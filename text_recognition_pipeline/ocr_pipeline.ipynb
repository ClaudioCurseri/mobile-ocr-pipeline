# %% [markdown]
# # OCR Pipeline
#
# TODO: Description

# %% [markdown]
# # Install dependencies
#
# Install the dependencies defined in the `requirements.txt`. This should preferrably be done in a virtual environment (venv). Then, set the kernel to the environment.
#
# ```
# python -m venv .venv
# source ./.venv/bin/activate
# pip install -r path/to/requirements.txt
# ```

# %% [markdown]
# # Running the pipeline
#
# ## Visualize a sample from the dataset
#
# TODO

# %%
from pipeline.text_recognition_pipeline import TextRecognitionPipeline

pipeline = TextRecognitionPipeline()

pipeline.run("evaluation/test_dataset/testDataset/input_test/00001.jpg")

# %% [markdown]
# # Evaluation
#
# TODO
